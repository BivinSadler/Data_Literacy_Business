# %% [markdown]
# <a href="https://colab.research.google.com/github/BivinSadler/Data_Literacy_Business/blob/main/DL_6_6_Import_Data_from_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data From GitHub

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/BivinSadler/Data_Literacy_Business/main/Balance.csv'

Balance = pd.read_csv(url)

display(Balance)
# Out:
#    index  subject genderage  Control  Treatment1 Treatment2
# 0      0        1   32_Male      7.9        12.3       10.7
# 1      1        2      45_F      6.3        10.6          ?
# 2      2        3      27_F      9.5        13.1       13.8
# 3      3        3      27_F      9.5        13.1       13.8
# 4      4        4      23_M      NaN        13.4       12.9
