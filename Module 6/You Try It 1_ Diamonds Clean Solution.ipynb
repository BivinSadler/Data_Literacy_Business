# %% [markdown]
# # Data Wrangle: Diamonds Data

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Import Data

# %%
# File location and type
file_location = "/FileStore/tables/diamonds-1.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

Diamonds = df.toPandas()
Diamonds
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#       <th>quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10378</td>
#       <td>43</td>
#       <td>54.0</td>
#       <td>4778</td>
#       <td>6.53</td>
#       <td>6.55</td>
#       <td>4.12</td>
#       <td>JVS2_1.09_Ideal</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4519</td>
#       <td>43</td>
#       <td>59.0</td>
#       <td>3634</td>
#       <td>6.32</td>
#       <td>6.27</td>
#       <td>3.97</td>
#       <td>GSI1_1_Fair</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6342</td>
#       <td>44</td>
#       <td>53.0</td>
#       <td>4032</td>
#       <td>6.31</td>
#       <td>6.24</td>
#       <td>4.12</td>
#       <td>GVS2_1_Fair</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16858</td>
#       <td>50.8</td>
#       <td>60.0</td>
#       <td>6727</td>
#       <td>7.73</td>
#       <td>7.25</td>
#       <td>3.93</td>
#       <td>IVS1_1.43_Fair</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>36504</td>
#       <td>51</td>
#       <td>67.0</td>
#       <td>945</td>
#       <td>4.67</td>
#       <td>4.62</td>
#       <td>2.37</td>
#       <td>EVVS2_0.3_Fair</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>53942</th>
#       <td>2013</td>
#       <td></td>
#       <td>59.0</td>
#       <td>3103</td>
#       <td>5.93</td>
#       <td>5.88</td>
#       <td>3.65</td>
#       <td>DSI1_0.78_Premium</td>
#     </tr>
#     <tr>
#       <th>53943</th>
#       <td>1306</td>
#       <td></td>
#       <td>62.0</td>
#       <td>2955</td>
#       <td>6.14</td>
#       <td>6.02</td>
#       <td>3.78</td>
#       <td>IVS1_0.89_Premium</td>
#     </tr>
#     <tr>
#       <th>53944</th>
#       <td>468</td>
#       <td>_</td>
#       <td>57.0</td>
#       <td>2818</td>
#       <td>6.07</td>
#       <td>6.00</td>
#       <td>3.68</td>
#       <td>HSI1_0.8_Ideal</td>
#     </tr>
#     <tr>
#       <th>53945</th>
#       <td>17</td>
#       <td>?</td>
#       <td>54.0</td>
#       <td>348</td>
#       <td>4.31</td>
#       <td>4.34</td>
#       <td>2.68</td>
#       <td>ISI2_0.3_Ideal</td>
#     </tr>
#     <tr>
#       <th>53946</th>
#       <td>966</td>
#       <td>?</td>
#       <td>61.0</td>
#       <td>2891</td>
#       <td>5.70</td>
#       <td>5.73</td>
#       <td>3.56</td>
#       <td>DVS2_0.71_Good</td>
#     </tr>
#   </tbody>
# </table>
# <p>53947 rows × 8 columns</p>
# </div>

# %% [markdown]
# ## Create 4 columns for the 4 Cs

# %%
Diamonds['Color'] = Diamonds['quality'].str.slice(start = 0, stop = 1)
Diamonds['CCC'] = Diamonds['quality'].str.slice(start = 1)
Diamonds[['Clarity','Caret','Cut']] = Diamonds['CCC'].str.split("_",n = 2,expand = True)
Diamonds
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#       <th>quality</th>
#       <th>Color</th>
#       <th>CCC</th>
#       <th>Clarity</th>
#       <th>Caret</th>
#       <th>Cut</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10378</td>
#       <td>43</td>
#       <td>54.0</td>
#       <td>4778</td>
#       <td>6.53</td>
#       <td>6.55</td>
#       <td>4.12</td>
#       <td>JVS2_1.09_Ideal</td>
#       <td>J</td>
#       <td>VS2_1.09_Ideal</td>
#       <td>VS2</td>
#       <td>1.09</td>
#       <td>Ideal</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4519</td>
#       <td>43</td>
#       <td>59.0</td>
#       <td>3634</td>
#       <td>6.32</td>
#       <td>6.27</td>
#       <td>3.97</td>
#       <td>GSI1_1_Fair</td>
#       <td>G</td>
#       <td>SI1_1_Fair</td>
#       <td>SI1</td>
#       <td>1</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6342</td>
#       <td>44</td>
#       <td>53.0</td>
#       <td>4032</td>
#       <td>6.31</td>
#       <td>6.24</td>
#       <td>4.12</td>
#       <td>GVS2_1_Fair</td>
#       <td>G</td>
#       <td>VS2_1_Fair</td>
#       <td>VS2</td>
#       <td>1</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16858</td>
#       <td>50.8</td>
#       <td>60.0</td>
#       <td>6727</td>
#       <td>7.73</td>
#       <td>7.25</td>
#       <td>3.93</td>
#       <td>IVS1_1.43_Fair</td>
#       <td>I</td>
#       <td>VS1_1.43_Fair</td>
#       <td>VS1</td>
#       <td>1.43</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>36504</td>
#       <td>51</td>
#       <td>67.0</td>
#       <td>945</td>
#       <td>4.67</td>
#       <td>4.62</td>
#       <td>2.37</td>
#       <td>EVVS2_0.3_Fair</td>
#       <td>E</td>
#       <td>VVS2_0.3_Fair</td>
#       <td>VVS2</td>
#       <td>0.3</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>53942</th>
#       <td>2013</td>
#       <td></td>
#       <td>59.0</td>
#       <td>3103</td>
#       <td>5.93</td>
#       <td>5.88</td>
#       <td>3.65</td>
#       <td>DSI1_0.78_Premium</td>
#       <td>D</td>
#       <td>SI1_0.78_Premium</td>
#       <td>SI1</td>
#       <td>0.78</td>
#       <td>Premium</td>
#     </tr>
#     <tr>
#       <th>53943</th>
#       <td>1306</td>
#       <td></td>
#       <td>62.0</td>
#       <td>2955</td>
#       <td>6.14</td>
#       <td>6.02</td>
#       <td>3.78</td>
#       <td>IVS1_0.89_Premium</td>
#       <td>I</td>
#       <td>VS1_0.89_Premium</td>
#       <td>VS1</td>
#       <td>0.89</td>
#       <td>Premium</td>
#     </tr>
#     <tr>
#       <th>53944</th>
#       <td>468</td>
#       <td>_</td>
#       <td>57.0</td>
#       <td>2818</td>
#       <td>6.07</td>
#       <td>6.00</td>
#       <td>3.68</td>
#       <td>HSI1_0.8_Ideal</td>
#       <td>H</td>
#       <td>SI1_0.8_Ideal</td>
#       <td>SI1</td>
#       <td>0.8</td>
#       <td>Ideal</td>
#     </tr>
#     <tr>
#       <th>53945</th>
#       <td>17</td>
#       <td>?</td>
#       <td>54.0</td>
#       <td>348</td>
#       <td>4.31</td>
#       <td>4.34</td>
#       <td>2.68</td>
#       <td>ISI2_0.3_Ideal</td>
#       <td>I</td>
#       <td>SI2_0.3_Ideal</td>
#       <td>SI2</td>
#       <td>0.3</td>
#       <td>Ideal</td>
#     </tr>
#     <tr>
#       <th>53946</th>
#       <td>966</td>
#       <td>?</td>
#       <td>61.0</td>
#       <td>2891</td>
#       <td>5.70</td>
#       <td>5.73</td>
#       <td>3.56</td>
#       <td>DVS2_0.71_Good</td>
#       <td>D</td>
#       <td>VS2_0.71_Good</td>
#       <td>VS2</td>
#       <td>0.71</td>
#       <td>Good</td>
#     </tr>
#   </tbody>
# </table>
# <p>53947 rows × 13 columns</p>
# </div>

# %% [markdown]
# ## drop quality and CCC columns

# %%
Diamonds = Diamonds.drop(['quality','CCC'], axis = 1)
Diamonds
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#       <th>Color</th>
#       <th>Clarity</th>
#       <th>Caret</th>
#       <th>Cut</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10378</td>
#       <td>43</td>
#       <td>54.0</td>
#       <td>4778</td>
#       <td>6.53</td>
#       <td>6.55</td>
#       <td>4.12</td>
#       <td>J</td>
#       <td>VS2</td>
#       <td>1.09</td>
#       <td>Ideal</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4519</td>
#       <td>43</td>
#       <td>59.0</td>
#       <td>3634</td>
#       <td>6.32</td>
#       <td>6.27</td>
#       <td>3.97</td>
#       <td>G</td>
#       <td>SI1</td>
#       <td>1</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6342</td>
#       <td>44</td>
#       <td>53.0</td>
#       <td>4032</td>
#       <td>6.31</td>
#       <td>6.24</td>
#       <td>4.12</td>
#       <td>G</td>
#       <td>VS2</td>
#       <td>1</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16858</td>
#       <td>50.8</td>
#       <td>60.0</td>
#       <td>6727</td>
#       <td>7.73</td>
#       <td>7.25</td>
#       <td>3.93</td>
#       <td>I</td>
#       <td>VS1</td>
#       <td>1.43</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>36504</td>
#       <td>51</td>
#       <td>67.0</td>
#       <td>945</td>
#       <td>4.67</td>
#       <td>4.62</td>
#       <td>2.37</td>
#       <td>E</td>
#       <td>VVS2</td>
#       <td>0.3</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>53942</th>
#       <td>2013</td>
#       <td></td>
#       <td>59.0</td>
#       <td>3103</td>
#       <td>5.93</td>
#       <td>5.88</td>
#       <td>3.65</td>
#       <td>D</td>
#       <td>SI1</td>
#       <td>0.78</td>
#       <td>Premium</td>
#     </tr>
#     <tr>
#       <th>53943</th>
#       <td>1306</td>
#       <td></td>
#       <td>62.0</td>
#       <td>2955</td>
#       <td>6.14</td>
#       <td>6.02</td>
#       <td>3.78</td>
#       <td>I</td>
#       <td>VS1</td>
#       <td>0.89</td>
#       <td>Premium</td>
#     </tr>
#     <tr>
#       <th>53944</th>
#       <td>468</td>
#       <td>_</td>
#       <td>57.0</td>
#       <td>2818</td>
#       <td>6.07</td>
#       <td>6.00</td>
#       <td>3.68</td>
#       <td>H</td>
#       <td>SI1</td>
#       <td>0.8</td>
#       <td>Ideal</td>
#     </tr>
#     <tr>
#       <th>53945</th>
#       <td>17</td>
#       <td>?</td>
#       <td>54.0</td>
#       <td>348</td>
#       <td>4.31</td>
#       <td>4.34</td>
#       <td>2.68</td>
#       <td>I</td>
#       <td>SI2</td>
#       <td>0.3</td>
#       <td>Ideal</td>
#     </tr>
#     <tr>
#       <th>53946</th>
#       <td>966</td>
#       <td>?</td>
#       <td>61.0</td>
#       <td>2891</td>
#       <td>5.70</td>
#       <td>5.73</td>
#       <td>3.56</td>
#       <td>D</td>
#       <td>VS2</td>
#       <td>0.71</td>
#       <td>Good</td>
#     </tr>
#   </tbody>
# </table>
# <p>53947 rows × 11 columns</p>
# </div>

# %% [markdown]
# ## detect inconsistent labels in Cut, Color and Clarity

# %%
print(Diamonds['Cut'].value_counts())
print(Diamonds['Color'].value_counts())
print(Diamonds['Clarity'].value_counts())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Ideal        21555
# Premium      13790
# Very Good    12083
# Good          4905
# Fair          1609
# premium          2
# good             1
# fair             1
# ?                1
# Name: Cut, dtype: int64
# G    11290
# E     9796
# F     9544
# H     8304
# D     6775
# I     5423
# J     2807
# f        3
# ?        3
# e        1
# g        1
# Name: Color, dtype: int64
# SI1     13065
# VS2     12260
# SI2      9197
# VS1      8172
# VVS2     5067
# VVS1     3655
# IF       1790
# I1        741
# Name: Clarity, dtype: int64
# </div>

# %% [markdown]
# ## Standardize Cut and Color Levels and Replace ? with NaN

# %%
import numpy as np
Diamonds["Cut"] = Diamonds["Cut"].replace("premium","Premium")
Diamonds["Cut"] = Diamonds["Cut"].replace("good","Good")
Diamonds["Cut"] = Diamonds["Cut"].replace("fair","Fair")
Diamonds["Cut"] = Diamonds["Cut"].replace("?",np.nan)
print(Diamonds['Cut'].value_counts())
Diamonds["Color"] = Diamonds["Color"].replace("e","E")
Diamonds["Color"] = Diamonds["Color"].replace("f","F")
Diamonds["Color"] = Diamonds["Color"].replace("g","G")
Diamonds["Color"] = Diamonds["Color"].replace("?",np.nan)
print(Diamonds['Color'].value_counts())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Ideal        21555
# Premium      13792
# Very Good    12083
# Good          4906
# Fair          1610
# Name: Cut, dtype: int64
# G    11291
# E     9797
# F     9547
# H     8304
# D     6775
# I     5423
# J     2807
# Name: Color, dtype: int64
# </div>

# %% [markdown]
# ## Look For Missing Values or Unusual Values in Numerical Columns

# %%
print(Diamonds.info())
Diamonds.isnull().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 53947 entries, 0 to 53946
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       53947 non-null  int32
#  1   depth    53947 non-null  object
#  2   table    53947 non-null  float64
#  3   price    53947 non-null  int32
#  4   x        53947 non-null  float64
#  5   y        53947 non-null  float64
#  6   z        53947 non-null  float64
#  7   Color    53944 non-null  object
#  8   Clarity  53947 non-null  object
#  9   Caret    53947 non-null  object
#  10  Cut      53946 non-null  object
# dtypes: float64(4), int32(2), object(5)
# memory usage: 4.1+ MB
# None
# Out[38]: ID         0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# Color      3
# Clarity    0
# Caret      0
# Cut        1
# dtype: int64</div>

# %% [markdown]
# ## Detect Duplicate Rows

# %%
print(Diamonds.duplicated().sum())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">6
# </div>

# %% [markdown]
# ## Drop Duplicated Rows

# %%
Diamonds = Diamonds.drop_duplicates()
print(Diamonds.duplicated().sum())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0
# </div>

# %% [markdown]
# ## Beware of the Unexpected

# %%
print(Diamonds.loc[Diamonds.duplicated(['ID'],keep = False)])
Diamonds = Diamonds.loc[-((Diamonds['ID']==17) & (Diamonds['depth'].isnull()))]
Diamonds.loc[Diamonds['ID']==17]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">       ID depth  table  price     x     y     z Color Clarity Caret    Cut
# 29501  17    62   54.0    348  4.31  4.34  2.68     I     SI2   0.3  Ideal
# 53945  17     ?   54.0    348  4.31  4.34  2.68     I     SI2   0.3  Ideal
# Out[41]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#       <th>Color</th>
#       <th>Clarity</th>
#       <th>Caret</th>
#       <th>Cut</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>29501</th>
#       <td>17</td>
#       <td>62</td>
#       <td>54.0</td>
#       <td>348</td>
#       <td>4.31</td>
#       <td>4.34</td>
#       <td>2.68</td>
#       <td>I</td>
#       <td>SI2</td>
#       <td>0.3</td>
#       <td>Ideal</td>
#     </tr>
#     <tr>
#       <th>53945</th>
#       <td>17</td>
#       <td>?</td>
#       <td>54.0</td>
#       <td>348</td>
#       <td>4.31</td>
#       <td>4.34</td>
#       <td>2.68</td>
#       <td>I</td>
#       <td>SI2</td>
#       <td>0.3</td>
#       <td>Ideal</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Change all '?' to NaN

# %%
Diamonds = Diamonds.replace("?",np.nan) # Change all "?" to NaN
Diamonds = Diamonds.loc[-((Diamonds['ID']==17) & (Diamonds['depth'].isnull()))]
Diamonds.loc[Diamonds['ID']==17]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#       <th>Color</th>
#       <th>Clarity</th>
#       <th>Caret</th>
#       <th>Cut</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>29501</th>
#       <td>17</td>
#       <td>62</td>
#       <td>54.0</td>
#       <td>348</td>
#       <td>4.31</td>
#       <td>4.34</td>
#       <td>2.68</td>
#       <td>I</td>
#       <td>SI2</td>
#       <td>0.3</td>
#       <td>Ideal</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## All Together

# %%
# Import Pandas
import pandas as pd

# File location and type
file_location = "/FileStore/tables/diamonds.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

Diamonds = df.toPandas()


# Create 4 columns for the 4 Cs
Diamonds['Color'] = Diamonds['quality'].str.slice(start = 0, stop = 1)
Diamonds['CCC'] = Diamonds['quality'].str.slice(start = 1)
Diamonds[['Clarity','Caret','Cut']] = Diamonds['CCC'].str.split("_",n = 2,expand = True)

# drop quality and CCC columns
Diamonds = Diamonds.drop(['quality','CCC'], axis = 1)

# Standardize Cut and Color Levels and Replace ? with NaN
import numpy as np
Diamonds["Cut"] = Diamonds["Cut"].replace("premium","Premium")
Diamonds["Cut"] = Diamonds["Cut"].replace("good","Good")
Diamonds["Cut"] = Diamonds["Cut"].replace("fair","Fair")
Diamonds["Cut"] = Diamonds["Cut"].replace("?",None)

Diamonds["Color"] = Diamonds["Color"].replace("e","E")
Diamonds["Color"] = Diamonds["Color"].replace("f","F")
Diamonds["Color"] = Diamonds["Color"].replace("g","G")
Diamonds["Color"] = Diamonds["Color"].replace("?",None)

# Change all "?" to NaN
Diamonds = Diamonds.replace("?",np.nan)

# Drop Duplicated Rows
Diamonds = Diamonds.drop_duplicates()

# Delete duplicate that has missing values: Search ID number
Diamonds = Diamonds.loc[-((Diamonds['ID']==17) & (Diamonds['depth'].isnull()))]

Diamonds
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[43]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#       <th>Color</th>
#       <th>Clarity</th>
#       <th>Caret</th>
#       <th>Cut</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10378</td>
#       <td>43</td>
#       <td>54.0</td>
#       <td>4778</td>
#       <td>6.53</td>
#       <td>6.55</td>
#       <td>4.12</td>
#       <td>J</td>
#       <td>VS2</td>
#       <td>1.09</td>
#       <td>Ideal</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4519</td>
#       <td>43</td>
#       <td>59.0</td>
#       <td>3634</td>
#       <td>6.32</td>
#       <td>6.27</td>
#       <td>3.97</td>
#       <td>G</td>
#       <td>SI1</td>
#       <td>1</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6342</td>
#       <td>44</td>
#       <td>53.0</td>
#       <td>4032</td>
#       <td>6.31</td>
#       <td>6.24</td>
#       <td>4.12</td>
#       <td>G</td>
#       <td>VS2</td>
#       <td>1</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16858</td>
#       <td>50.8</td>
#       <td>60.0</td>
#       <td>6727</td>
#       <td>7.73</td>
#       <td>7.25</td>
#       <td>3.93</td>
#       <td>I</td>
#       <td>VS1</td>
#       <td>1.43</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>36504</td>
#       <td>51</td>
#       <td>67.0</td>
#       <td>945</td>
#       <td>4.67</td>
#       <td>4.62</td>
#       <td>2.37</td>
#       <td>E</td>
#       <td>VVS2</td>
#       <td>0.3</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>53941</th>
#       <td>52861</td>
#       <td>79</td>
#       <td>73.0</td>
#       <td>2579</td>
#       <td>5.21</td>
#       <td>5.18</td>
#       <td>4.09</td>
#       <td>E</td>
#       <td>VS2</td>
#       <td>0.5</td>
#       <td>Fair</td>
#     </tr>
#     <tr>
#       <th>53942</th>
#       <td>2013</td>
#       <td></td>
#       <td>59.0</td>
#       <td>3103</td>
#       <td>5.93</td>
#       <td>5.88</td>
#       <td>3.65</td>
#       <td>D</td>
#       <td>SI1</td>
#       <td>0.78</td>
#       <td>Premium</td>
#     </tr>
#     <tr>
#       <th>53943</th>
#       <td>1306</td>
#       <td></td>
#       <td>62.0</td>
#       <td>2955</td>
#       <td>6.14</td>
#       <td>6.02</td>
#       <td>3.78</td>
#       <td>I</td>
#       <td>VS1</td>
#       <td>0.89</td>
#       <td>Premium</td>
#     </tr>
#     <tr>
#       <th>53944</th>
#       <td>468</td>
#       <td>_</td>
#       <td>57.0</td>
#       <td>2818</td>
#       <td>6.07</td>
#       <td>6.00</td>
#       <td>3.68</td>
#       <td>H</td>
#       <td>SI1</td>
#       <td>0.8</td>
#       <td>Ideal</td>
#     </tr>
#     <tr>
#       <th>53946</th>
#       <td>966</td>
#       <td>NaN</td>
#       <td>61.0</td>
#       <td>2891</td>
#       <td>5.70</td>
#       <td>5.73</td>
#       <td>3.56</td>
#       <td>D</td>
#       <td>VS2</td>
#       <td>0.71</td>
#       <td>Good</td>
#     </tr>
#   </tbody>
# </table>
# <p>53940 rows × 11 columns</p>
# </div>
